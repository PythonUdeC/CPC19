# %%
#%matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd #audio
from imageio import imread #scipy.misc.imread fue/será eliminado!

# %% [markdown]
# # Audio cargado

# %%
ipd.Audio('./datas/CongaGroove-mono.wav') # load a local WAV file
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Audio Generado

# %%
sr = 22050 # Tasa de sampleo
f = 440. #Hz
T = 1/f # periodo en segundos
tmax = 2. # tiempo max en segundos
t = np.linspace(0, tmax, int(tmax*sr), endpoint=False) # tiempo variable
A = 0.5 # amplitud de la onda
x = A*np.sin(2*np.pi*f*t)# onda sinusoidal a f=440 Hz

# %%
T
# Out:
# 0.0022727272727272726

# %%
x
# Out:
# array([ 0.        ,  0.06252526,  0.12406892, ..., -0.1836648 ,
#        -0.12406892, -0.06252526])

# %%
t
# Out:
# array([0.00000000e+00, 4.53514739e-05, 9.07029478e-05, ...,
#        1.99986395e+00, 1.99990930e+00, 1.99995465e+00])

# %%
ipd.Audio(x, rate=sr) #reprodude el array1d de numpy
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(t,x,'.')
plt.xlabel('$t$')
plt.ylabel('$x(t)$')
# Out:
# Text(0, 0.5, '$x(t)$')

# %%
ipd.Audio(x[0:200], rate=sr) #reprodude el array1d de numpy
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(t[0:200],x[0:200],'.')
plt.xlabel('$t$')
plt.ylabel('$x(t)$')
# Out:
# Text(0, 0.5, '$x(t)$')

# %% [markdown]
# https://musicinformationretrieval.com/ipython_audio.html

# %% [markdown]
# # Imágen generada

# %%
imagen1 = np.random.rand(500,500)
print(imagen1)
# Out:
# [[0.62230564 0.70058976 0.76349387 ... 0.18304257 0.44518233 0.41439439]
#  [0.68160637 0.40162776 0.31605199 ... 0.65041097 0.89805152 0.16218084]
#  [0.07387637 0.20272206 0.98176864 ... 0.3756211  0.66919318 0.36063305]
#  ...
#  [0.67093859 0.99697067 0.83135348 ... 0.45057926 0.23717925 0.94409043]
#  [0.83736234 0.08504482 0.42055799 ... 0.39243432 0.09868018 0.21910598]
#  [0.85058398 0.04575986 0.45716771 ... 0.29451572 0.52469892 0.48118613]]

# %%
plt.figure(figsize=(8,8))
plt.imshow(imagen1, cmap='gray')

# %% [markdown]
# # Imágen cargada

# %%
foto = imread('./images/naty_ganando.jpg')

# %%
type(foto)
# Out:
# imageio.core.util.Array

# %%
np.shape(foto)
# Out:
# (1536, 2048, 3)

# %%
plt.figure(figsize=(8,8))
plt.imshow(foto)

# %% [markdown]
# # Rojo

# %%
filtro_rojo = foto[:,:,0]
print(filtro_rojo)
# Out:
# [[132 125 131 ...  62  64  65]
#  [124 125 126 ...  63  64  64]
#  [109 107 102 ...  62  62  63]
#  ...
#  [169 172 182 ...  67  75  78]
#  [195 193 197 ...  65  68  67]
#  [212 211 215 ...  71  72  65]]

# %%
plt.figure(figsize=(8,8))
plt.imshow(filtro_rojo, cmap='Reds')

# %%
filtro_verde = foto[:,:,1]
print(filtro_verde)
# Out:
# [[ 98  91  97 ...  57  59  60]
#  [ 89  90  91 ...  58  59  59]
#  [ 69  67  62 ...  57  57  58]
#  ...
#  [163 166 176 ...  43  51  55]
#  [189 187 191 ...  41  44  44]
#  [206 205 209 ...  47  48  42]]

# %% [markdown]
# # Verde

# %%
plt.figure(figsize=(8,8))
plt.imshow(filtro_verde, cmap='Greens')

# %% [markdown]
# # Azul

# %%
filtro_azul = foto[:,:,2]
print(filtro_azul)
# Out:
# [[ 71  64  70 ...  61  63  64]
#  [ 61  62  63 ...  62  63  63]
#  [ 43  41  36 ...  61  61  62]
#  ...
#  [173 176 186 ...  39  47  49]
#  [199 197 201 ...  37  40  38]
#  [216 215 219 ...  43  44  36]]

# %%
plt.figure(figsize=(8,8))
plt.imshow(filtro_azul, cmap='Blues')

# %%
foto_copia = foto.copy()
foto_copia[500:700, 100:800, :] = [200,255, 0]

# %%
plt.figure(figsize=(8,8))
plt.imshow(foto_copia)
