# %%
#%matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd #audio
from imageio import imread #scipy.misc.imread fue/será eliminado!

# %% [markdown]
# # Audio cargado

# %%
ipd.Audio('./datas/CongaGroove-mono.wav') # load a local WAV file
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Audio Generado

# %%
sr = 22050 # Tasa de sampleo
f = 440. #Hz
T = 1/f # periodo en segundos
tmax = 2. # tiempo max en segundos
t = np.linspace(0, tmax, int(tmax*sr), endpoint=False) # tiempo variable
A = 0.5 # amplitud de la onda
x = A*np.sin(2*np.pi*f*t)# onda sinusoidal a f=440 Hz

# %%
T
# Out:
# 0.0022727272727272726

# %%
x
# Out:
# array([ 0.        ,  0.06252526,  0.12406892, ..., -0.1836648 ,
#        -0.12406892, -0.06252526])

# %%
t
# Out:
# array([0.00000000e+00, 4.53514739e-05, 9.07029478e-05, ...,
#        1.99986395e+00, 1.99990930e+00, 1.99995465e+00])

# %%
ipd.Audio(x, rate=sr) #reprodude el array1d de numpy
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(t,x,'.')
plt.xlabel(r'$t$')
plt.ylabel(r'$x(t)$')
# Out:
# Text(0, 0.5, '$x(t)$')

# %%
ipd.Audio(x[0:200], rate=sr) #reprodude el array1d de numpy
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(t[0:200],x[0:200],'.')
plt.xlabel('$t$')
plt.ylabel('$x(t)$')
# Out:
# Text(0, 0.5, '$x(t)$')

# %% [markdown]
# https://musicinformationretrieval.com/ipython_audio.html

# %% [markdown]
# # Imágen generada

# %%
imagen1 = np.random.rand(500,500)
print(imagen1)
# Out:
# [[0.69731888 0.84904746 0.13230645 ... 0.34775901 0.79009845 0.00562892]
#  [0.31906902 0.28922688 0.91019561 ... 0.68342531 0.36880308 0.77265079]
#  [0.25565802 0.57462615 0.96451041 ... 0.85666673 0.94821398 0.16172089]
#  ...
#  [0.38610756 0.38768654 0.84952552 ... 0.88751024 0.89135232 0.17904411]
#  [0.55191136 0.86376747 0.40693884 ... 0.29203938 0.01353509 0.70569804]
#  [0.80401708 0.77526204 0.23364465 ... 0.21931218 0.8508331  0.27205847]]

# %%
plt.figure(figsize=(8,8))
plt.imshow(imagen1, cmap='gray')

# %% [markdown]
# # Imágen cargada

# %%
foto = imread('./images/IMG_20190109_144618.jpg')

# %%
type(foto)
# Out:
# imageio.core.util.Array

# %%
np.shape(foto)
# Out:
# (3000, 4000, 3)

# %%
plt.figure(figsize=(8,8))
plt.imshow(foto)

# %% [markdown]
# # Rojo

# %%
filtro_rojo = foto[:,:,0]
print(filtro_rojo)
# Out:
# [[254 255 254 ... 118 123 126]
#  [254 255 253 ... 112 118 121]
#  [253 255 252 ... 113 118 121]
#  ...
#  [161 166 166 ...  52  55  52]
#  [165 166 164 ...  52  51  50]
#  [160 165 163 ...  56  53  53]]

# %%
plt.figure(figsize=(8,8))
plt.imshow(filtro_rojo, cmap='Reds')

# %%
filtro_verde = foto[:,:,1]
print(filtro_verde)
# Out:
# [[249 250 249 ... 127 132 135]
#  [249 251 248 ... 122 127 130]
#  [248 250 247 ... 123 127 130]
#  ...
#  [121 125 125 ...  71  74  71]
#  [126 125 123 ...  71  70  69]
#  [121 124 122 ...  75  72  72]]

# %% [markdown]
# # Verde

# %%
plt.figure(figsize=(8,8))
plt.imshow(filtro_verde, cmap='Greens')

# %% [markdown]
# # Azul

# %%
filtro_azul = foto[:,:,2]
print(filtro_azul)
# Out:
# [[245 246 245 ... 142 147 150]
#  [245 247 244 ... 134 142 145]
#  [244 246 243 ... 135 142 145]
#  ...
#  [ 26  33  33 ...  77  80  77]
#  [ 31  33  31 ...  77  76  75]
#  [ 26  32  30 ...  81  78  78]]

# %%
plt.figure(figsize=(8,8))
plt.imshow(filtro_azul, cmap='Blues')

# %%
emo = imread('./images/emoticon.png')

# %%
plt.figure(figsize=(8,8))
plt.imshow(emo)

# %%
for i in range(4):
    plt.figure(figsize=(8,8))
    plt.imshow(emo[:,:,i])

# %%
foto_copia = foto.copy()
foto_copia[1500:2012, 600:1112, :] = emo[:,:,0:3]

# %%
plt.figure(figsize=(8,8))
plt.imshow(foto_copia)
